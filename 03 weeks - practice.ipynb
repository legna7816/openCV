# %% [markdown]
# ex. 4-1

# %%
import numpy as np
import cv2

img = np.zeros((200,400), np.uint8)
img[:] = 200

title1, title2 = 'Position1', 'Position2'
cv2.namedWindow(title1, cv2.WINDOW_AUTOSIZE)
cv2.namedWindow(title2) # flag를 지정하지 않으면 기본값인 cv2.WINDOW_AUTOSIZE로 지정됨
cv2.moveWindow(title1, 150, 150)
cv2.moveWindow(title2, 400, 50)

cv2.imshow(title1, img)
cv2.imshow(title2, img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# 키가 입력되기 전까지는 창이 계속 열려있고 키를 입력하면 열린 윈도우가 모두 닫힘

# %% [markdown]
# ex. 4-2

# %%
import numpy as np
import cv2

img = np.zeros((200,300), np.uint8)
img.fill(255)

title1, title2 = 'AUTOSIZE', 'NORMAL'
cv2.namedWindow(title1, cv2.WINDOW_AUTOSIZE)
cv2.namedWindow(title2, cv2.WINDOW_NORMAL)

cv2.imshow(title1, img)
cv2.imshow(title2, img)
cv2.resizeWindow(title1, 400, 300)
cv2.resizeWindow(title2, 400, 300)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ex. 4-3

# %%
import numpy as np
import cv2

switch_case = {
    ord('a'): "a키 입력",
    ord('b'): "b키 입력",
    0x41: "A키 입력",
    int('0x42', 16): "B키 입력",
    2424832: "왼쪽 화살표키 입력",
    2490368: "위쪽 화살표키 입력",
    2555904: "오른쪽 화살표키 입력",
    2621440: "아래쪽 화살표키 입력"
}

img = np.ones((200,300), np.float64)
cv2.namedWindow('Keyboard Event')
cv2.imshow("Keyboard Event", img)

while True:
    key = cv2.waitKeyEx(100)
    if key == 27: break

    try:
        result = switch_case[key]
        print(result)
    except KeyError:
        result = -1

cv2.destroyAllWindows()
# Out:
# a키 입력
# b키 입력
# 위쪽 화살표키 입력
# 왼쪽 화살표키 입력
# 아래쪽 화살표키 입력
# 오른쪽 화살표키 입력

# %% [markdown]
# ex. 4-3(다른 버전)

# %%
import numpy as np
import cv2

img = np.zeros((100,100), np.uint8)
cv2.imshow("test", img)

while True:
    key = cv2.waitKeyEx(100)
    if key == 27: break
    elif key == -1: continue
    else:
        if key < 255: # ascii라면
            print(key, chr(key))
        else:
            print(key)

cv2.destroyAllWindows()
# Out:
# 113 q
# 113 q
# 119 w
# 101 e
# 114 r
# 97 a
# 115 s
# 100 d
# 102 f
# 122 z
# 120 x
# 99 c
# 118 v
# 96 `
# 49 1
# 50 2
# 51 3
# 51 3
# 52 4
# 53 5
# 54 6
# 55 7
# 56 8
# 57 9
# 48 0

# %% [markdown]
# Q. 키를 누르면 텍스트를 출력하는 대신 윈도우의 위치 이동

# %%
import numpy as np
import cv2

img = np.zeros((300,300), np.uint8)
cv2.imshow('img', img)
x, y = 200, 200

while True:
    cv2.moveWindow('img', x, y)
    key = cv2.waitKeyEx(100)
    if key == 27:
        break
    if key == ord('a'):
        x -= 10
    elif key == ord('w'):
        y -= 10
    elif key == ord('s'):
        y += 10
    elif key == ord('d'):
        x += 10

cv2.destroyAllWindows()

# %% [markdown]
# ex. 4-4

# %%
import numpy as np
import cv2

def onMouse(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print("마우스 왼쪽 버튼 누르기")
    elif event == cv2.EVENT_RBUTTONDOWN:
        print("마우스 오른쪽 버튼 누르기")
    elif event == cv2.EVENT_RBUTTONUP:
        print("마우스 오른쪽 버튼 떼기")
    elif event == cv2.EVENT_LBUTTONDBLCLK:
        print("마우스 왼쪽 버튼 더블클릭")

img = np.full((200, 300), 255, np.uint8)

title1, title2 = "Mouse Event1", "Mouse Event2"
cv2.imshow(title1, img)
cv2.imshow(title2, img)

cv2.setMouseCallback(title1, onMouse)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 마우스 왼쪽 버튼 누르기
# 마우스 왼쪽 버튼 누르기
# 마우스 왼쪽 버튼 누르기
# 마우스 왼쪽 버튼 누르기
# 마우스 왼쪽 버튼 더블클릭
# 마우스 왼쪽 버튼 누르기
# 마우스 왼쪽 버튼 더블클릭
# 마우스 오른쪽 버튼 누르기
# 마우스 오른쪽 버튼 떼기
# 마우스 오른쪽 버튼 누르기
# 마우스 오른쪽 버튼 떼기
# 마우스 오른쪽 버튼 누르기
# 마우스 오른쪽 버튼 떼기
# 마우스 오른쪽 버튼 떼기
# 마우스 왼쪽 버튼 누르기
# 마우스 왼쪽 버튼 더블클릭
# 마우스 왼쪽 버튼 누르기

# %% [markdown]
# Q. 마우스 왼쪽 버튼과 동시에 Shift, Ctrl, Alt키 누르기

# %%
import numpy as np
import cv2

def onMouse(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print("마우스 왼쪽 버튼 누르기")
        if flags & cv2.EVENT_FLAG_CTRLKEY:
            print('ctrl키 누르기')
        if flags & cv2.EVENT_FLAG_SHIFTKEY:
            print('shift키 누르기')
        if flags & cv2.EVENT_FLAG_ALTKEY:
            print('Alt키 누르기')
    elif event == cv2.EVENT_RBUTTONDOWN:
        print("마우스 오른쪽 버튼 누르기")
    elif event == cv2.EVENT_RBUTTONUP:
        print("마우스 오른쪽 버튼 떼기")
    elif event == cv2.EVENT_LBUTTONDBLCLK:
        print("마우스 왼쪽 버튼 더블클릭")

img = np.full((200, 300), 255, np.uint8)

title1, title2 = "Mouse Event1", "Mouse Event2"
cv2.imshow(title1, img)
cv2.imshow(title2, img)

cv2.setMouseCallback(title1, onMouse)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 마우스 왼쪽 버튼 누르기
# 마우스 왼쪽 버튼 누르기
# ctrl키 누르기
# 마우스 오른쪽 버튼 누르기
# 마우스 오른쪽 버튼 떼기
# 마우스 왼쪽 버튼 누르기
# ctrl키 누르기
# 마우스 왼쪽 버튼 누르기
# shift키 누르기
# 마우스 왼쪽 버튼 누르기
# shift키 누르기
# 마우스 왼쪽 버튼 더블클릭

# %% [markdown]
# ex. 4-5

# %%
import numpy as np
import cv2

def onChange(value):
    global img, title

    # 오류가 발생하는 이유: 넘파이 배열의 dtype이 uint8이라 음수가 표현이 되지 않음
    # 트랙바를 클릭해서 51로 옮기면 int(img[0][0])의 값이 0에서 51로 바뀜
    # 그리고 왼쪽을 클릭해서 0으로 가게 되면 0 - 51 = -51가 되어 add_value는 -51이 됨->오류
    add_value = value - int(img[0][0])
    print("추가 화소값: ", add_value)

    # img = img + add_value
    
    # int16으로 변환해 음수든 양수든 계산에 오류가 없게 함, 트랙바 이동값만큼 현재 이미지에 누적 밝기 적용
    a = img.astype(np.int16) + add_value # 현재 값 기준으로 변화량을 계산
    
    a[a<0] = 0
    a[a>255] = 255 # 범위를 0~255로 제한
    
    img[:] = a.astype(np.uint8) # 배열의 모든 원소를 덮어쓰기 위함
    
    cv2.imshow(title, img)

img = np.zeros((300, 500), np.uint8)

title = 'Trackbar Event'
cv2.imshow(title, img)

cv2.createTrackbar('Brightness', title, img[0][0], 255, onChange)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 추가 화소값:  51
# 추가 화소값:  51
# 추가 화소값:  -51
# 추가 화소값:  -51
# 추가 화소값:  51
# 추가 화소값:  51
# 추가 화소값:  51
# 추가 화소값:  51
# 추가 화소값:  51
# 추가 화소값:  -51
# 추가 화소값:  -51
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -2
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -2
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -2
# 추가 화소값:  -2
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -2
# 추가 화소값:  -1
# 추가 화소값:  -2
# 추가 화소값:  -2
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -2
# 추가 화소값:  -2
# 추가 화소값:  -2
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -2
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# 추가 화소값:  -1
# ...
